# %% [markdown]
# Importing Required Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pickle

# %% [markdown]
# Read The Dtaset

# %%
df=pd.read_csv('Dataset.csv',encoding='ISO-8859-1')

# %%
df.head()
# Out:
#        dateCrawled                            name  seller offerType  price  \
# 0  3/24/2016 11:52                      Golf_3_1.6  privat   Angebot    480
# 1  3/24/2016 10:58            A5_Sportback_2.7_Tdi  privat   Angebot  18300
# 2  3/14/2016 12:52  Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800
# 3  3/17/2016 16:54             GOLF_4_1_4__3TÃRER  privat   Angebot   1500
# 4  3/31/2016 17:25  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600
#
#   abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0   test         NaN                1993    manuell        0   golf
# 1   test       coupe                2011    manuell      190    NaN
# 2   test         suv                2004  automatik      163  grand
# 3   test  kleinwagen                2001    manuell       75   golf
# 4   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#       dateCreated  nrOfPictures  postalCode         lastSeen
# 0  3/24/2016 0:00             0       70435    4/7/2016 3:16
# 1  3/24/2016 0:00             0       66954    4/7/2016 1:46
# 2  3/14/2016 0:00             0       90480   4/5/2016 12:47
# 3  3/17/2016 0:00             0       91074  3/17/2016 17:40
# 4  3/31/2016 0:00             0       60437   4/6/2016 10:17

# %%
df.tail()
# Out:
#           dateCrawled                                               name  \
# 5011  3/30/2016 15:57        BMW_e46_Cabrio_mit_Hardtop_echter_Hingucker
# 5012  3/11/2016 15:37               Ford_Focus_Turnier_1.6_TDCi_DPF_Ghia
# 5013    4/5/2016 3:02  Mercedes_Benz_C_200_T_CDI_DPF__BlueEFFICIENCY_...
# 5014  3/24/2016 19:54                 Citroen_C1_Selection_Sonder_Modell
# 5015  3/14/2016 10:50         Audi_A3_Sportback_3.2_quattro_DSG_Ambition
#
#       seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 5011  privat   Angebot   9500     test      cabrio                2004
# 5012  privat   Angebot   5700     test       kombi                2009
# 5013  privat   Angebot  12900     test       kombi                2012
# 5014  privat   Angebot   6500  control  kleinwagen                2011
# 5015  privat   Angebot   8900  control   limousine                2004
#
#         gearbox  powerPS     model  kilometer  monthOfRegistration fuelType  \
# 5011        NaN      170       3er     150000                    6      NaN
# 5012    manuell      109     focus     150000                    3   diesel
# 5013  automatik      136  c_klasse     150000                    1   diesel
# 5014    manuell        0        c1      60000                   10      NaN
# 5015  automatik      250        a3     150000                   11   benzin
#
#               brand notRepairedDamage     dateCreated  nrOfPictures  \
# 5011            bmw              nein  3/30/2016 0:00             0
# 5012           ford              nein  3/11/2016 0:00             0
# 5013  mercedes_benz              nein   4/5/2016 0:00             0
# 5014        citroen               NaN  3/24/2016 0:00             0
# 5015           audi              nein  3/14/2016 0:00             0
#
#       postalCode        lastSeen
# 5011       71691   4/7/2016 7:16
# 5012       19230  4/5/2016 14:17
# 5013       77948  4/7/2016 11:16
# 5014       21745  3/29/2016 6:47
# 5015       74336  4/1/2016 14:44

# %%
df.shape
# Out:
# (5016, 20)

# %% [markdown]
# Cleaning The Dataset

# %%
df.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
# Droping the Unwanted Columns
df.drop(columns= ['seller', 'offerType', 'nrOfPictures'], inplace = True)

# %%
df.drop(columns= ['dateCrawled', 'dateCreated','name', 'lastSeen'], inplace = True)

# %% [markdown]
# Handle The Missing Values

# %%
#check missing values
df.isnull().sum()
# Out:
# price                    0
# abtest                   0
# vehicleType            555
# yearOfRegistration       0
# gearbox                274
# powerPS                  0
# model                  259
# kilometer                0
# monthOfRegistration      0
# fuelType               484
# brand                    0
# notRepairedDamage      977
# postalCode               0
# dtype: int64

# %%
#replacing the missing values
df['vehicleType'].fillna(df['vehicleType'].mode()[0], inplace = True)
df['gearbox'].fillna(df['gearbox'].mode()[0], inplace = True)
df['model'].fillna(df['model'].mode()[0], inplace = True)
df['fuelType'].fillna(df['fuelType'].mode()[0], inplace = True)
df['notRepairedDamage'].fillna(df['notRepairedDamage'].mode()[0], inplace = True)

# %%
df.head()
# Out:
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test   limousine                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190   golf
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen              nein
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep              nein
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#    postalCode
# 0       70435
# 1       66954
# 2       90480
# 3       91074
# 4       60437

# %%
df.tail()
# Out:
#       price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 5011   9500     test      cabrio                2004    manuell      170
# 5012   5700     test       kombi                2009    manuell      109
# 5013  12900     test       kombi                2012  automatik      136
# 5014   6500  control  kleinwagen                2011    manuell        0
# 5015   8900  control   limousine                2004  automatik      250
#
#          model  kilometer  monthOfRegistration fuelType          brand  \
# 5011       3er     150000                    6   benzin            bmw
# 5012     focus     150000                    3   diesel           ford
# 5013  c_klasse     150000                    1   diesel  mercedes_benz
# 5014        c1      60000                   10   benzin        citroen
# 5015        a3     150000                   11   benzin           audi
#
#      notRepairedDamage  postalCode
# 5011              nein       71691
# 5012              nein       19230
# 5013              nein       77948
# 5014              nein       21745
# 5015              nein       74336

# %%
df.isnull().sum()
# Out:
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# postalCode             0
# dtype: int64

# %% [markdown]
# Remove The Duplicates Values

# %%
# Checking for Duplicates
df.duplicated().sum()
# Out:
# 5

# %%
# Removing Duplicates
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Split The Data Into Dependent And Independent Variables.

# %%
x=df.drop(columns=['price'],axis=1)
x
# Out:
#        abtest vehicleType  yearOfRegistration    gearbox  powerPS     model  \
# 0        test   limousine                1993    manuell        0      golf
# 1        test       coupe                2011    manuell      190      golf
# 2        test         suv                2004  automatik      163     grand
# 3        test  kleinwagen                2001    manuell       75      golf
# 4        test  kleinwagen                2008    manuell       69     fabia
# ...       ...         ...                 ...        ...      ...       ...
# 5011     test      cabrio                2004    manuell      170       3er
# 5012     test       kombi                2009    manuell      109     focus
# 5013     test       kombi                2012  automatik      136  c_klasse
# 5014  control  kleinwagen                2011    manuell        0        c1
# 5015  control   limousine                2004  automatik      250        a3
#
#       kilometer  monthOfRegistration fuelType          brand  \
# 0        150000                    0   benzin     volkswagen
# 1        125000                    5   diesel           audi
# 2        125000                    8   diesel           jeep
# 3        150000                    6   benzin     volkswagen
# 4         90000                    7   diesel          skoda
# ...         ...                  ...      ...            ...
# 5011     150000                    6   benzin            bmw
# 5012     150000                    3   diesel           ford
# 5013     150000                    1   diesel  mercedes_benz
# 5014      60000                   10   benzin        citroen
# 5015     150000                   11   benzin           audi
#
#      notRepairedDamage  postalCode
# 0                 nein       70435
# 1                   ja       66954
# 2                 nein       90480
# 3                 nein       91074
# 4                 nein       60437
# ...                ...         ...
# 5011              nein       71691
# 5012              nein       19230
# 5013              nein       77948
# 5014              nein       21745
# 5015              nein       74336
#
# [5011 rows x 12 columns]

# %%
y = df['price']
y
# Out:
# 0         480
# 1       18300
# 2        9800
# 3        1500
# 4        3600
#         ...
# 5011     9500
# 5012     5700
# 5013    12900
# 5014     6500
# 5015     8900
# Name: price, Length: 5011, dtype: int64
